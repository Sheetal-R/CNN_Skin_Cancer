# %% [markdown]
# <a href="https://colab.research.google.com/github/Sheetal-R/CNN_Skin_Cancer/blob/main/sheetalr_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem statement:** To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution that can evaluate images and alert dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.</br>
#
# **Project Pipeline**
# - Data Reading/Data Understanding → Defining the path for train and test images
# - Dataset Creation→ Create train & validation dataset from the train directory with a batch size of 32. Also, make sure you resize your images to 180*180.
# - Dataset visualisation → Create a code to visualize one instance of all the nine classes present in the dataset
# - Model Building & training :
#   - Create a CNN model, which can accurately detect 9 classes present in the dataset. While building the model, rescale images to normalize pixel values between (0,1).
#   - Choose an appropriate optimiser and loss function for model training
#   - Train the model for ~20 epochs
#   - Write your findings after the model fit. You must check if there is any evidence of model overfit or underfit.
# - Chose an appropriate data augmentation strategy to resolve underfitting/overfitting
# - Model Building & training on the augmented data :
#   - Create a CNN model, which can accurately detect 9 classes present in the dataset. While building the model rescale images to normalize pixel values between (0,1).
#   - Choose an appropriate optimiser and loss function for model training
#   - Train the model for ~20 epochs
#   - Write your findings after the model fit, see if the earlier issue is resolved or not?
# - Class distribution: Examine the current class distribution in the training dataset
#   - Which class has the least number of samples?
#   - Which classes dominate the data in terms of the proportionate number of samples?
# - Handling class imbalances: Rectify class imbalances present in the training dataset with Augmentor library.
# - Model Building & training on the rectified class imbalance data :
#   - Create a CNN model, which can accurately detect 9 classes present in the dataset. While building the model, rescale images to normalize pixel values between (0,1).
#   - Choose an appropriate optimiser and loss function for model training
#   - Train the model for ~30 epochs
#   - Write your findings after the model fit, see if the issues are resolved or not?

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Jul 12 14:26:49 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# #### Importing Libraries

# %%
# !pip install -q keras

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from google.colab import drive
from glob import  glob

# %% [markdown]
# ### Mount Google Drive and use path to import the train and test data

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Defining the path for train and test images
data_dir_train = pathlib.Path("/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %% [markdown]
# Create DF to View Data

# %%
# Create dataframes
train_df = pd.DataFrame(columns=['image_path', 'label'])
test_df = pd.DataFrame(columns=['image_path', 'label'])

# %%
# Add images paths and labels to dataframes

def appendDictToDF(df,dictToAppend):
  df = pd.concat([df, pd.DataFrame.from_records([dictToAppend])])
  return df


for label, directory in enumerate(os.listdir(data_dir_train)):
    for filename in os.listdir(os.path.join(data_dir_train, directory)):
        image_path = os.path.join(data_dir_train, directory, filename)
        #train_df = train_df.append({'image_path': image_path, 'label': label}, ignore_index=True)
        train_df = appendDictToDF(train_df,{'image_path': image_path, 'label': label})


for label, directory in enumerate(os.listdir(data_dir_test)):
    for filename in os.listdir(os.path.join(data_dir_test, directory)):
        image_path = os.path.join(data_dir_test, directory, filename)
        test_df = appendDictToDF(test_df,{'image_path': image_path, 'label': label})

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (2239, 2)
# (118, 2)

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %%
# Get list of directories in train_dir
labels = os.listdir(data_dir_train)

# Create label_map dictionary
label_map = {i: label for i, label in enumerate(labels)}
num_classes=len(label_map)
label_map
# Out:
# {0: 'actinic keratosis',
#  1: 'nevus',
#  2: 'seborrheic keratosis',
#  3: 'dermatofibroma',
#  4: 'pigmented benign keratosis',
#  5: 'vascular lesion',
#  6: 'squamous cell carcinoma',
#  7: 'basal cell carcinoma',
#  8: 'melanoma'}

# %%
# Count the number of images in each class
class_counts = train_df['label'].value_counts().sort_index()

# Print the number of images in each class
print("Dataset Summary")
print("-" * 60)
print(f"{'Class Label':<15} {'Class Name':<30} {'Count':<10}")
print("-" * 60)
for class_label, class_name in label_map.items():
    count = class_counts[class_label]
    print(f"{class_label:<15} {class_name:<30} {count:<10}")
print("-" * 60)
print(f"{'Total':<45} {sum(class_counts):<10}")
# Out:
# Dataset Summary
# ------------------------------------------------------------
# Class Label     Class Name                     Count
# ------------------------------------------------------------
# 0               actinic keratosis              114
# 1               nevus                          357
# 2               seborrheic keratosis           77
# 3               dermatofibroma                 95
# 4               pigmented benign keratosis     462
# 5               vascular lesion                139
# 6               squamous cell carcinoma        181
# 7               basal cell carcinoma           376
# 8               melanoma                       438
# ------------------------------------------------------------
# Total                                         2239

# %% [markdown]
# Found 2239 files belonging to 9 classes.

# %%
# Count the number of images in each class
class_counts = test_df['label'].value_counts().sort_index()

# Print the number of images in each class
print("Dataset Summary")
print("-" * 60)
print(f"{'Class Label':<15} {'Class Name':<30} {'Count':<10}")
print("-" * 60)
for class_label, class_name in label_map.items():
    count = class_counts[class_label]
    print(f"{class_label:<15} {class_name:<30} {count:<10}")
print("-" * 60)
print(f"{'Total':<45} {sum(class_counts):<10}")
# Out:
# Dataset Summary
# ------------------------------------------------------------
# Class Label     Class Name                     Count
# ------------------------------------------------------------
# 0               actinic keratosis              16
# 1               nevus                          3
# 2               seborrheic keratosis           3
# 3               dermatofibroma                 16
# 4               pigmented benign keratosis     16
# 5               vascular lesion                16
# 6               squamous cell carcinoma        16
# 7               basal cell carcinoma           16
# 8               melanoma                       16
# ------------------------------------------------------------
# Total                                         118

# %% [markdown]
# Found 118 files belonging to 9 classes.

# %% [markdown]
# #### **Visualising the data**

# %%
train_df_one = {}
class_counts = train_df['label'].value_counts()
for class_label, class_name in label_map.items():
    count = class_counts[class_label]
    train_df_one[class_name] = count

names, values = zip(*sorted(train_df_one.items(), key= lambda x: x[1], reverse=True))
print(names)

plt.figure()
plt.bar(names, values, width=0.9)

# add Bar labels
for c in plt.gca().containers:
   plt.gca().bar_label(c)
plt.xticks(rotation=90)
plt.show()
# Out:
# ('pigmented benign keratosis', 'melanoma', 'basal cell carcinoma', 'nevus', 'squamous cell carcinoma', 'vascular lesion', 'actinic keratosis', 'dermatofibroma', 'seborrheic keratosis')

# %%
test_df_one = {}
class_counts = test_df['label'].value_counts()
for class_label, class_name in label_map.items():
    count = class_counts[class_label]
    test_df_one[class_name] = count

names, values = zip(*sorted(test_df_one.items(), key= lambda x: x[1], reverse=True))
print(names)

plt.figure()
plt.bar(names, values, width=0.9)

# add Bar labels
for c in plt.gca().containers:
   plt.gca().bar_label(c)
plt.xticks(rotation=90)
plt.show()
# Out:
# ('actinic keratosis', 'dermatofibroma', 'pigmented benign keratosis', 'vascular lesion', 'squamous cell carcinoma', 'basal cell carcinoma', 'melanoma', 'nevus', 'seborrheic keratosis')

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# **A typical Convolution Neural Network(CNN)**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_test,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 118 files belonging to 9 classes.
# Using 23 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(3):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model - normalize pixel values between (0,1)

# %%
### Your code goes here
num_classes = 9 # as target class has 9 labels
model = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.Rescaling(1.0/255),
  tf.keras.layers.Conv2D(32, (3, 3), padding="same", activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(128, (3, 3), padding="same", activation='relu'),
  tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(256, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(num_classes)
  # No Softmax Activation layer implied from_logits=True
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.build(input_shape=(None,180,180,3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 88, 88, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 44, 44, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 42, 42, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 21, 21, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 128)       73856
#
#  conv2d_4 (Conv2D)           (None, 19, 19, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 256)         295168
#
#  max_pooling2d_4 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dense_1 (Dense)             (None, 9)                 4617
#
# =================================================================
# Total params: 1,730,025
# Trainable params: 1,730,025
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 233s 113ms/step - loss: 1.9930 - accuracy: 0.2394 - val_loss: 2.2725 - val_accuracy: 0.2609
# Epoch 2/20
# 56/56 [==============================] - 2s 28ms/step - loss: 1.8103 - accuracy: 0.3225 - val_loss: 3.0077 - val_accuracy: 0.2174
# Epoch 3/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.7971 - accuracy: 0.3320 - val_loss: 3.3970 - val_accuracy: 0.1304
# Epoch 4/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.6003 - accuracy: 0.4269 - val_loss: 2.3915 - val_accuracy: 0.2174
# Epoch 5/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.5220 - accuracy: 0.4565 - val_loss: 2.4636 - val_accuracy: 0.3043
# Epoch 6/20
# 56/56 [==============================] - 1s 27ms/step - loss: 1.4723 - accuracy: 0.4810 - val_loss: 3.0579 - val_accuracy: 0.3043
# Epoch 7/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.4196 - accuracy: 0.5011 - val_loss: 2.4568 - val_accuracy: 0.2609
# Epoch 8/20
# 56/56 [==============================] - 1s 27ms/step - loss: 1.4041 - accuracy: 0.4911 - val_loss: 3.0317 - val_accuracy: 0.2174
# Epoch 9/20
# 56/56 [==============================] - 1s 26ms/step - loss: 1.4169 - accuracy: 0.4950 - val_loss: 2.6575 - val_accuracy: 0.2609
# Epoch 10/20
# 56/56 [==============================] - 1s 26ms/step - loss: 1.3540 - accuracy: 0.5162 - val_loss: 2.2486 - val_accuracy: 0.3478
# Epoch 11/20
# 56/56 [==============================] - 1s 27ms/step - loss: 1.3128 - accuracy: 0.5229 - val_loss: 2.5140 - val_accuracy: 0.3043
# Epoch 12/20
# 56/56 [==============================] - 1s 27ms/step - loss: 1.2596 - accuracy: 0.5430 - val_loss: 2.7498 - val_accuracy: 0.3043
# Epoch 13/20
# 56/56 [==============================] - 1s 27ms/step - loss: 1.2681 - accuracy: 0.5363 - val_loss: 2.6392 - val_accuracy: 0.1304
# Epoch 14/20
# 56/56 [==============================] - 1s 27ms/step - loss: 1.2082 - accuracy: 0.5658 - val_loss: 2.7457 - val_accuracy: 0.3043
# Epoch 15/20
# 56/56 [==============================] - 1s 27ms/step - loss: 1.1906 - accuracy: 0.5686 - val_loss: 2.7575 - val_accuracy: 0.2174
# Epoch 16/20
# 56/56 [==============================] - 1s 27ms/step - loss: 1.1311 - accuracy: 0.5781 - val_loss: 2.6120 - val_accuracy: 0.2174
# Epoch 17/20
# 56/56 [==============================] - 1s 27ms/step - loss: 1.1615 - accuracy: 0.5748 - val_loss: 2.8649 - val_accuracy: 0.2609
# Epoch 18/20
# 56/56 [==============================] - 1s 26ms/step - loss: 1.0736 - accuracy: 0.6044 - val_loss: 3.2346 - val_accuracy: 0.3043
# Epoch 19/20
# 56/56 [==============================] - 1s 27ms/step - loss: 1.1064 - accuracy: 0.5904 - val_loss: 3.2671 - val_accuracy: 0.2609
# Epoch 20/20
# 56/56 [==============================] - 1s 27ms/step - loss: 1.0065 - accuracy: 0.6244 - val_loss: 2.9584 - val_accuracy: 0.2174

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Findings** :
# - model is overfitting with train data</br>
# We can see this with high amount of validation loss and reduce in validation accuracy

# %% [markdown]
# ### Write your findings here

# %%
# augumentation strategy.
# Your code goes here
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal_and_vertical", input_shape=(img_height, img_width, 3)),
  tf.keras.layers.RandomRotation(0.7),
  tf.keras.layers.RandomZoom(0.1),
  tf.keras.layers.GaussianNoise(stddev=0.1)
])

# %%
# visualizing how the augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.experimental.preprocessing.Rescaling(1.0/255),
  tf.keras.layers.Conv2D(32, (3, 3), padding="same", activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Dropout(0.25),
  tf.keras.layers.Conv2D(128, (3, 3), padding="same", activation='relu'),
  tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(256, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Dropout(0.25),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ***ReduceLROnPlateau*** is a callback in Keras that reduces the learning rate of the optimizer when a metric plateaus. This can help to prevent the model from overfitting the training data.

# %%
val_accuracy_callback = tf.keras.callbacks.ReduceLROnPlateau(
  monitor='val_accuracy', patience=3, factor=0.3, min_lr=0.0001, verbose=1
)

# %%
model.build(input_shape=(None,180,180,3))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 180, 180, 32)      896
#
#  max_pooling2d_5 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 88, 88, 32)        9248
#
#  max_pooling2d_6 (MaxPooling  (None, 44, 44, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 42, 42, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 21, 21, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 21, 21, 64)        0
#
#  conv2d_9 (Conv2D)           (None, 21, 21, 128)       73856
#
#  conv2d_10 (Conv2D)          (None, 19, 19, 128)       147584
#
#  max_pooling2d_8 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 256)         295168
#
#  max_pooling2d_9 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 3, 3, 256)         0
#
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_2 (Dense)             (None, 512)               1180160
#
#  dense_3 (Dense)             (None, 9)                 4617
#
# =================================================================
# Total params: 1,730,025
# Trainable params: 1,730,025
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
batch_size=32
history = model.fit(
  train_ds,
  batch_size=batch_size,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[val_accuracy_callback])
# Out:
# Epoch 1/20
# 56/56 [==============================] - 6s 50ms/step - loss: 2.0487 - accuracy: 0.1897 - val_loss: 2.4861 - val_accuracy: 0.0435 - lr: 0.0010
# Epoch 2/20
# 56/56 [==============================] - 3s 47ms/step - loss: 1.9556 - accuracy: 0.2494 - val_loss: 2.2101 - val_accuracy: 0.1739 - lr: 0.0010
# Epoch 3/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.8276 - accuracy: 0.2930 - val_loss: 2.6840 - val_accuracy: 0.0870 - lr: 0.0010
# Epoch 4/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.7211 - accuracy: 0.3605 - val_loss: 2.4053 - val_accuracy: 0.2609 - lr: 0.0010
# Epoch 5/20
# 56/56 [==============================] - 3s 45ms/step - loss: 1.6584 - accuracy: 0.3890 - val_loss: 3.5250 - val_accuracy: 0.0870 - lr: 0.0010
# Epoch 6/20
# 56/56 [==============================] - 3s 45ms/step - loss: 1.5664 - accuracy: 0.4342 - val_loss: 2.4339 - val_accuracy: 0.3043 - lr: 0.0010
# Epoch 7/20
# 56/56 [==============================] - 3s 45ms/step - loss: 1.5137 - accuracy: 0.4581 - val_loss: 2.5443 - val_accuracy: 0.2174 - lr: 0.0010
# Epoch 8/20
# 56/56 [==============================] - 3s 45ms/step - loss: 1.4493 - accuracy: 0.4799 - val_loss: 2.7628 - val_accuracy: 0.3478 - lr: 0.0010
# Epoch 9/20
# 56/56 [==============================] - 2s 45ms/step - loss: 1.4521 - accuracy: 0.4916 - val_loss: 3.1762 - val_accuracy: 0.2174 - lr: 0.0010
# Epoch 10/20
# 56/56 [==============================] - 3s 45ms/step - loss: 1.4390 - accuracy: 0.4961 - val_loss: 2.6674 - val_accuracy: 0.3043 - lr: 0.0010
# Epoch 11/20
# 55/56 [============================>.] - ETA: 0s - loss: 1.4063 - accuracy: 0.4864
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 56/56 [==============================] - 3s 45ms/step - loss: 1.4081 - accuracy: 0.4833 - val_loss: 2.3058 - val_accuracy: 0.3043 - lr: 0.0010
# Epoch 12/20
# 56/56 [==============================] - 3s 45ms/step - loss: 1.3467 - accuracy: 0.5257 - val_loss: 2.6810 - val_accuracy: 0.3478 - lr: 3.0000e-04
# Epoch 13/20
# 56/56 [==============================] - 2s 45ms/step - loss: 1.3014 - accuracy: 0.5324 - val_loss: 2.4882 - val_accuracy: 0.3478 - lr: 3.0000e-04
# Epoch 14/20
# 55/56 [============================>.] - ETA: 0s - loss: 1.2969 - accuracy: 0.5290
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001.
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2975 - accuracy: 0.5296 - val_loss: 2.8404 - val_accuracy: 0.3478 - lr: 3.0000e-04
# Epoch 15/20
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2677 - accuracy: 0.5413 - val_loss: 2.5904 - val_accuracy: 0.3478 - lr: 1.0000e-04
# Epoch 16/20
# 56/56 [==============================] - 2s 45ms/step - loss: 1.2576 - accuracy: 0.5413 - val_loss: 2.6770 - val_accuracy: 0.3043 - lr: 1.0000e-04
# Epoch 17/20
# 56/56 [==============================] - 2s 45ms/step - loss: 1.2556 - accuracy: 0.5413 - val_loss: 2.4487 - val_accuracy: 0.3478 - lr: 1.0000e-04
# Epoch 18/20
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2526 - accuracy: 0.5513 - val_loss: 2.6768 - val_accuracy: 0.3043 - lr: 1.0000e-04
# Epoch 19/20
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2495 - accuracy: 0.5452 - val_loss: 2.6003 - val_accuracy: 0.3043 - lr: 1.0000e-04
# Epoch 20/20
# 56/56 [==============================] - 2s 45ms/step - loss: 1.2401 - accuracy: 0.5480 - val_loss: 2.8423 - val_accuracy: 0.3043 - lr: 1.0000e-04

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Yes there is still scope for improvement. The issue is with the amount of training data. Since we have very less training data we might add augument and create more samples.

# %% [markdown]
# #### Distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
labels = {0 : "actinic", 1: "basel", 2: "dermatofibroma", 3: "melanoma", 4: "nevus",
          5: "pigmented", 6: "seborrheic", 7: "squamous", 8: "vascular"}

def get_classes_distribution(data):
    # Get the count for each label
    label_counts = data['label'].value_counts()

    # Get total number of samples
    total_samples = len(data)


    # Count the number of items in each class
    for i in range(len(label_counts)):
        label = labels[label_counts.index[i]]
        count = label_counts.values[i]
        percent = (count / total_samples) * 100
        print("{:<20s}:   {} or {}%".format(label, count, percent))

# %%
get_classes_distribution(train_df)
# Out:
# nevus               :   462 or 20.634211701652525%
# vascular            :   438 or 19.56230460026798%
# squamous            :   376 or 16.793211255024566%
.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000368.jpg_b949bafb-cfcf-4205-be1d-e62d3963b4c7.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000430.jpg_438dff16-4e11-48c3-b709-62f32844923d.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000220.jpg_6826fada-a734-47a5-9924-db5470f4ad44.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000534.jpg_d1fbeb05-207f-47fd-9ac8-b24d8271d75a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000250.jpg_69f44b08-c62b-482e-99c7-870e9abb2ce9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000237.jpg_7a42d71c-262e-4995-9889-81023f5af392.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000465.jpg_958c3c4b-32bc-46a9-bb54-5a5b69ff9456.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000336.jpg_d085a979-ef5d-46bb-8b20-3994af411a72.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000240.jpg_30de465c-3710-49f4-8831-7604d27c35df.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000063.jpg_1145ecfd-9b30-433a-9d3f-49f75738acad.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000328.jpg_6c2c0ba9-3ef7-4faf-80e4-8bca6ae3da20.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000230.jpg_b2f23082-8d72-43ac-89e7-d1fe5fb1f8c0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000512.jpg_723698c1-c844-4016-955f-5e30fc5222cc.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000328.jpg_d6823b48-fc95-4f71-990e-4e6fc28a5672.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000503.jpg_ce3006da-289f-4aa6-aeb3-750ff4c3518b.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0027668.jpg_05ae7a05-affe-465b-aa8d-71b36531b232.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0028314.jpg_955649d7-8f18-461e-935b-ff87bc6f3698.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000021.jpg_767aa67b-31ed-471c-bb28-f59dd9fff548.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000388.jpg_d251ef7d-1023-457c-b20e-7033ee5c3e50.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0029025.jpg_d42b90d9-f824-44c3-bab8-b5ae546d5979.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000496.jpg_d24aef9e-33ec-4674-b06e-399bfa96f408.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0029133.jpg_dbbc14a2-6bd8-41e1-874c-8ea194f70266.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000092.jpg_01f335e0-7a37-4a03-86bc-a2004fc9d61e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000508.jpg_78ee71a0-c452-4005-9a90-1d619b450f01.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000375.jpg_f84b0ed8-2bd5-4d19-9ac2-b6090e5b2f87.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000376.jpg_3294e43d-c9a5-4cfe-956e-52c71642048f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000439.jpg_2f177728-b07c-4a7d-b71b-0db2a71a2d22.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
path_list = [x for x in glob(os.path.join(data_dir_train,'*','*.jpg'))]

# %%
lesion_list = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train,'*','*.jpg'))]

# %%
dataframe_dict = dict(zip(path_list, lesion_list))

# %%
original_df = pd.DataFrame(list(dataframe_dict.items()),columns=['Path','Label'])

# %%
original_df['Label'].value_counts()
# Out:
# Train    2239
# Name: Label, dtype: int64

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)
# Out:
# <ipython-input-48-17a6b079869a>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()
# Out:
# Train                         2239
# actinic keratosis              500
# nevus                          500
# seborrheic keratosis           500
# dermatofibroma                 500
# pigmented benign keratosis     500
# vascular lesion                500
# squamous cell carcinoma        500
# basal cell carcinoma           500
# melanoma                       500
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# ####  Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# ####  Create a training dataset

# %%
data_dir_train="/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %%
data_dir_test = "/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/"
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_test,
  seed=123,
  validation_split = 0.2,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 118 files belonging to 9 classes.
# Using 23 files for validation.

# %% [markdown]
# #### Create model

# %%
## your code goes here
num_classes = 9
model = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.Rescaling(1.0/255),
  tf.keras.layers.Conv2D(32, (3, 3), padding="same", activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(128, (3, 3), padding="same", activation='relu'),
  tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(256, (3, 3), activation='relu'),
  #tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(num_classes)
  # No Softmax Activation layer implied from_logits=True
])

# %% [markdown]
# #### Compile your model

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
callback = tf.keras.callbacks.ReduceLROnPlateau(
  monitor='val_accuracy', patience=3, factor=0.1, min_lr=0.0001, verbose=1
)

# %%
model.build(input_shape=(None,180,180,3))

# %% [markdown]
# ####  Train your model

# %%
epochs = 30
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs, callbacks=[callback]
)
# Out:
# Epoch 1/30
# 169/169 [==============================] -
- val_accuracy: 0.8025 - lr: 0.0010
# Epoch 21/30
# 169/169 [==============================] - 21s 119ms/step - loss: 0.2556 - accuracy: 0.9065 - val_loss: 0.7671 - val_accuracy: 0.8166 - lr: 0.0010
# Epoch 22/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.2149 - accuracy: 0.9180
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 169/169 [==============================] - 21s 123ms/step - loss: 0.2150 - accuracy: 0.9178 - val_loss: 0.8637 - val_accuracy: 0.7914 - lr: 0.0010
# Epoch 23/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.1348 - accuracy: 0.9457 - val_loss: 0.6511 - val_accuracy: 0.8627 - lr: 1.0000e-04
# Epoch 24/30
# 169/169 [==============================] - 21s 118ms/step - loss: 0.1106 - accuracy: 0.9547 - val_loss: 0.6603 - val_accuracy: 0.8641 - lr: 1.0000e-04
# Epoch 25/30
# 169/169 [==============================] - 22s 126ms/step - loss: 0.1037 - accuracy: 0.9555 - val_loss: 0.6747 - val_accuracy: 0.8641 - lr: 1.0000e-04
# Epoch 26/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.0996 - accuracy: 0.9551 - val_loss: 0.6847 - val_accuracy: 0.8604 - lr: 1.0000e-04
# Epoch 27/30
# 169/169 [==============================] - 21s 121ms/step - loss: 0.0985 - accuracy: 0.9555 - val_loss: 0.7042 - val_accuracy: 0.8649 - lr: 1.0000e-04
# Epoch 28/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.0952 - accuracy: 0.9557 - val_loss: 0.7064 - val_accuracy: 0.8641 - lr: 1.0000e-04
# Epoch 29/30
# 169/169 [==============================] - 21s 118ms/step - loss: 0.0935 - accuracy: 0.9564 - val_loss: 0.7196 - val_accuracy: 0.8656 - lr: 1.0000e-04
# Epoch 30/30
# 169/169 [==============================] - 21s 122ms/step - loss: 0.0907 - accuracy: 0.9560 - val_loss: 0.7318 - val_accuracy: 0.8664 - lr: 1.0000e-04

# %% [markdown]
# ####  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Analysis of results:
# - We can see that using Augumentor- the class imbalance was addressed by generating more sample images per class and aiding in learning process.
# - This also addressed the overfit problem which we were seeing in our initial model design
# - Model accuracy went up to nearly 80-90% which is significant

# %% [markdown]
# ## **Summary**
#  - Model Building & training :
#    - Created a CNN model, which can accurately detect 9 classes present in the dataset. While building the model, rescale images to normalize pixel values between (0,1).
#    - Selected 'adam' optimiser and loss function 'tf.losses.SparseCategoricalCrossentropy(from_logits=True)' for model training
#    - Train the model for ~20 epochs
#  - The data augmentation strategy with random zoom, rotation, flip was chosen to resolve overfitting
#  - Model Building & training on the augmented data :
#     - Created a CNN model, which can accurately detect 9 classes present in the dataset. While building the model rescale images to normalize pixel values between (0,1).
#     - Selected 'adam' optimiser and loss function 'tf.losses.SparseCategoricalCrossentropy(from_logits=True)' for model training
#     - Train the model for ~20 epochs
#     - The dropout helped in reducing the overfit problem along with data augumentation
#  - On examining the current class distribution in the training dataset
#     - classes dermatofibroma, melanoma least number of samples
#     - classes nevus, vascular dominate the data in terms proportionate number of samples
#  - Rectified class imbalances present in the training dataset with Augmentor library
#  - Model Building & training on the rectified class imbalance data :
#    - Created a CNN model, which can accurately detect 9 classes present in the dataset. While building the model rescale images to normalize pixel values between (0,1).
#     - Selected 'adam' optimiser and loss function 'tf.losses.SparseCategoricalCrossentropy(from_logits=True)' for model training
#     - Train the model for ~30 epochs
#     - This increased the model accuracy to nearly 80-90% which is very significant
