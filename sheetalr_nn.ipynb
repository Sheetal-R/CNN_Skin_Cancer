# %% [markdown]
# <a href="https://colab.research.google.com/github/Sheetal-R/CNN_Skin_Cancer/blob/main/sheetalr_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem statement:** To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution that can evaluate images and alert dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.</br>
#
# **Project Pipeline**
# - Data Reading/Data Understanding → Defining the path for train and test images
# - Dataset Creation→ Create train & validation dataset from the train directory with a batch size of 32. Also, make sure you resize your images to 180*180.
# - Dataset visualisation → Create a code to visualize one instance of all the nine classes present in the dataset
# - Model Building & training :
#   - Create a CNN model, which can accurately detect 9 classes present in the dataset. While building the model, rescale images to normalize pixel values between (0,1).
#   - Choose an appropriate optimiser and loss function for model training
#   - Train the model for ~20 epochs
#   - Write your findings after the model fit. You must check if there is any evidence of model overfit or underfit.
# - Chose an appropriate data augmentation strategy to resolve underfitting/overfitting
# - Model Building & training on the augmented data :
#   - Create a CNN model, which can accurately detect 9 classes present in the dataset. While building the model rescale images to normalize pixel values between (0,1).
#   - Choose an appropriate optimiser and loss function for model training
#   - Train the model for ~20 epochs
#   - Write your findings after the model fit, see if the earlier issue is resolved or not?
# - Class distribution: Examine the current class distribution in the training dataset
#   - Which class has the least number of samples?
#   - Which classes dominate the data in terms of the proportionate number of samples?
# - Handling class imbalances: Rectify class imbalances present in the training dataset with Augmentor library.
# - Model Building & training on the rectified class imbalance data :
#   - Create a CNN model, which can accurately detect 9 classes present in the dataset. While building the model, rescale images to normalize pixel values between (0,1).
#   - Choose an appropriate optimiser and loss function for model training
#   - Train the model for ~30 epochs
#   - Write your findings after the model fit, see if the issues are resolved or not?

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Jul 12 15:39:12 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# #### Importing Libraries

# %%
# !pip install -q keras

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from google.colab import drive
from glob import  glob

# %% [markdown]
# ### Mount Google Drive and use path to import the train and test data

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Defining the path for train and test images
data_dir_train = pathlib.Path("/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %% [markdown]
# Create DF to View Data

# %%
# Create dataframes
train_df = pd.DataFrame(columns=['image_path', 'label'])
test_df = pd.DataFrame(columns=['image_path', 'label'])

# %%
# Add images paths and labels to dataframes

def appendDictToDF(df,dictToAppend):
  df = pd.concat([df, pd.DataFrame.from_records([dictToAppend])])
  return df


for label, directory in enumerate(os.listdir(data_dir_train)):
    for filename in os.listdir(os.path.join(data_dir_train, directory)):
        image_path = os.path.join(data_dir_train, directory, filename)
        #train_df = train_df.append({'image_path': image_path, 'label': label}, ignore_index=True)
        train_df = appendDictToDF(train_df,{'image_path': image_path, 'label': label})


for label, directory in enumerate(os.listdir(data_dir_test)):
    for filename in os.listdir(os.path.join(data_dir_test, directory)):
        image_path = os.path.join(data_dir_test, directory, filename)
        test_df = appendDictToDF(test_df,{'image_path': image_path, 'label': label})

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (2239, 2)
# (118, 2)

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %%
# Get list of directories in train_dir
labels = os.listdir(data_dir_train)

# Create label_map dictionary
label_map = {i: label for i, label in enumerate(labels)}
num_classes=len(label_map)
label_map
# Out:
# {0: 'actinic keratosis',
#  1: 'nevus',
#  2: 'seborrheic keratosis',
#  3: 'dermatofibroma',
#  4: 'pigmented benign keratosis',
#  5: 'vascular lesion',
#  6: 'squamous cell carcinoma',
#  7: 'basal cell carcinoma',
#  8: 'melanoma'}

# %%
# Count the number of images in each class
class_counts = train_df['label'].value_counts().sort_index()

# Print the number of images in each class
print("Dataset Summary")
print("-" * 60)
print(f"{'Class Label':<15} {'Class Name':<30} {'Count':<10}")
print("-" * 60)
for class_label, class_name in label_map.items():
    count = class_counts[class_label]
    print(f"{class_label:<15} {class_name:<30} {count:<10}")
print("-" * 60)
print(f"{'Total':<45} {sum(class_counts):<10}")
# Out:
# Dataset Summary
# ------------------------------------------------------------
# Class Label     Class Name                     Count
# ------------------------------------------------------------
# 0               actinic keratosis              114
# 1               nevus                          357
# 2               seborrheic keratosis           77
# 3               dermatofibroma                 95
# 4               pigmented benign keratosis     462
# 5               vascular lesion                139
# 6               squamous cell carcinoma        181
# 7               basal cell carcinoma           376
# 8               melanoma                       438
# ------------------------------------------------------------
# Total                                         2239

# %% [markdown]
# Found 2239 files belonging to 9 classes.

# %%
# Count the number of images in each class
class_counts = test_df['label'].value_counts().sort_index()

# Print the number of images in each class
print("Dataset Summary")
print("-" * 60)
print(f"{'Class Label':<15} {'Class Name':<30} {'Count':<10}")
print("-" * 60)
for class_label, class_name in label_map.items():
    count = class_counts[class_label]
    print(f"{class_label:<15} {class_name:<30} {count:<10}")
print("-" * 60)
print(f"{'Total':<45} {sum(class_counts):<10}")
# Out:
# Dataset Summary
# ------------------------------------------------------------
# Class Label     Class Name                     Count
# ------------------------------------------------------------
# 0               actinic keratosis              16
# 1               nevus                          3
# 2               seborrheic keratosis           3
# 3               dermatofibroma                 16
# 4               pigmented benign keratosis     16
# 5               vascular lesion                16
# 6               squamous cell carcinoma        16
# 7               basal cell carcinoma           16
# 8               melanoma                       16
# ------------------------------------------------------------
# Total                                         118

# %% [markdown]
# Found 118 files belonging to 9 classes.

# %% [markdown]
# #### **Visualising the data**

# %%
train_df_one = {}
class_counts = train_df['label'].value_counts()
for class_label, class_name in label_map.items():
    count = class_counts[class_label]
    train_df_one[class_name] = count

names, values = zip(*sorted(train_df_one.items(), key= lambda x: x[1], reverse=True))
print(names)

plt.figure()
plt.bar(names, values, width=0.9)

# add Bar labels
for c in plt.gca().containers:
   plt.gca().bar_label(c)
plt.xticks(rotation=90)
plt.show()
# Out:
# ('pigmented benign keratosis', 'melanoma', 'basal cell carcinoma', 'nevus', 'squamous cell carcinoma', 'vascular lesion', 'actinic keratosis', 'dermatofibroma', 'seborrheic keratosis')

# %%
test_df_one = {}
class_counts = test_df['label'].value_counts()
for class_label, class_name in label_map.items():
    count = class_counts[class_label]
    test_df_one[class_name] = count

names, values = zip(*sorted(test_df_one.items(), key= lambda x: x[1], reverse=True))
print(names)

plt.figure()
plt.bar(names, values, width=0.9)

# add Bar labels
for c in plt.gca().containers:
   plt.gca().bar_label(c)
plt.xticks(rotation=90)
plt.show()
# Out:
# ('actinic keratosis', 'dermatofibroma', 'pigmented benign keratosis', 'vascular lesion', 'squamous cell carcinoma', 'basal cell carcinoma', 'melanoma', 'nevus', 'seborrheic keratosis')

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# **A typical Convolution Neural Network(CNN)**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_test,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 118 files belonging to 9 classes.
# Using 23 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(3):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model - normalize pixel values between (0,1)

# %%
### Your code goes here
num_classes = 9 # as target class has 9 labels
model = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.Rescaling(1.0/255),
  tf.keras.layers.Conv2D(32, (3, 3), padding="same", activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(128, (3, 3), padding="same", activation='relu'),
  tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(256, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(num_classes)
  # No Softmax Activation layer implied from_logits=True
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.build(input_shape=(None,180,180,3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 88, 88, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 44, 44, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 42, 42, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 21, 21, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 128)       73856
#
#  conv2d_4 (Conv2D)           (None, 19, 19, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 256)         295168
#
#  max_pooling2d_4 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dense_1 (Dense)             (None, 9)                 4617
#
# =================================================================
# Total params: 1,730,025
# Trainable params: 1,730,025
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 255s 132ms/step - loss: 2.0591 - accuracy: 0.1875 - val_loss: 2.3804 - val_accuracy: 0.1739
# Epoch 2/20
# 56/56 [==============================] - 2s 28ms/step - loss: 1.9520 - accuracy: 0.2561 - val_loss: 2.2134 - val_accuracy: 0.0870
# Epoch 3/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.7856 - accuracy: 0.3220 - val_loss: 2.4072 - val_accuracy: 0.2609
# Epoch 4/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.7111 - accuracy: 0.3694 - val_loss: 2.3165 - val_accuracy: 0.2609
# Epoch 5/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.5512 - accuracy: 0.4381 - val_loss: 2.9374 - val_accuracy: 0.1304
# Epoch 6/20
# 56/56 [==============================] - 1s 27ms/step - loss: 1.4832 - accuracy: 0.4754 - val_loss: 2.6325 - val_accuracy: 0.2609
# Epoch 7/20
# 56/56 [==============================] - 1s 27ms/step - loss: 1.4150 - accuracy: 0.5022 - val_loss: 2.8042 - val_accuracy: 0.3043
# Epoch 8/20
# 56/56 [==============================] - 1s 27ms/step - loss: 1.3680 - accuracy: 0.5128 - val_loss: 2.1511 - val_accuracy: 0.2609
# Epoch 9/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.3204 - accuracy: 0.5145 - val_loss: 2.8018 - val_accuracy: 0.2609
# Epoch 10/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.3130 - accuracy: 0.5268 - val_loss: 2.2920 - val_accuracy: 0.3043
# Epoch 11/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.3298 - accuracy: 0.5218 - val_loss: 2.1011 - val_accuracy: 0.3913
# Epoch 12/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.2819 - accuracy: 0.5391 - val_loss: 2.7055 - val_accuracy: 0.3478
# Epoch 13/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.2619 - accuracy: 0.5491 - val_loss: 2.6438 - val_accuracy: 0.3478
# Epoch 14/20
# 56/56 [==============================] - 1s 27ms/step - loss: 1.2146 - accuracy: 0.5631 - val_loss: 2.1571 - val_accuracy: 0.2174
# Epoch 15/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.2480 - accuracy: 0.5385 - val_loss: 1.9670 - val_accuracy: 0.3913
# Epoch 16/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.1915 - accuracy: 0.5592 - val_loss: 2.3442 - val_accuracy: 0.2609
# Epoch 17/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.2059 - accuracy: 0.5603 - val_loss: 2.4803 - val_accuracy: 0.2609
# Epoch 18/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.1069 - accuracy: 0.5965 - val_loss: 2.6422 - val_accuracy: 0.2609
# Epoch 19/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.1453 - accuracy: 0.5826 - val_loss: 2.2468 - val_accuracy: 0.3913
# Epoch 20/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.0954 - accuracy: 0.5988 - val_loss: 2.4160 - val_accuracy: 0.3043

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Findings** :
# - model is overfitting with train data</br>
# We can see this with high amount of validation loss and reduce in validation accuracy

# %% [markdown]
# ### Write your findings here

# %%
# augumentation strategy.
# Your code goes here
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal_and_vertical", input_shape=(img_height, img_width, 3)),
  tf.keras.layers.RandomRotation(0.7),
  tf.keras.layers.RandomZoom(0.1),
  tf.keras.layers.GaussianNoise(stddev=0.1)
])

# %%
# visualizing how the augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.experimental.preprocessing.Rescaling(1.0/255),
  tf.keras.layers.Conv2D(32, (3, 3), padding="same", activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Dropout(0.25),
  tf.keras.layers.Conv2D(128, (3, 3), padding="same", activation='relu'),
  tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(256, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Dropout(0.25),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ***ReduceLROnPlateau*** is a callback in Keras that reduces the learning rate of the optimizer when a metric plateaus. This can help to prevent the model from overfitting the training data.

# %%
val_accuracy_callback = tf.keras.callbacks.ReduceLROnPlateau(
  monitor='val_accuracy', patience=3, factor=0.3, min_lr=0.0001, verbose=1
)

# %%
model.build(input_shape=(None,180,180,3))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 180, 180, 32)      896
#
#  max_pooling2d_5 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 88, 88, 32)        9248
#
#  max_pooling2d_6 (MaxPooling  (None, 44, 44, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 42, 42, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 21, 21, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 21, 21, 64)        0
#
#  conv2d_9 (Conv2D)           (None, 21, 21, 128)       73856
#
#  conv2d_10 (Conv2D)          (None, 19, 19, 128)       147584
#
#  max_pooling2d_8 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 256)         295168
#
#  max_pooling2d_9 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 3, 3, 256)         0
#
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_2 (Dense)             (None, 512)               1180160
#
#  dense_3 (Dense)             (None, 9)                 4617
#
# =================================================================
# Total params: 1,730,025
# Trainable params: 1,730,025
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
batch_size=32
history = model.fit(
  train_ds,
  batch_size=batch_size,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[val_accuracy_callback])
# Out:
# Epoch 1/20
# 56/56 [==============================] - 6s 52ms/step - loss: 2.0521 - accuracy: 0.1735 - val_loss: 2.3113 - val_accuracy: 0.0870 - lr: 0.0010
# Epoch 2/20
# 56/56 [==============================] - 3s 49ms/step - loss: 1.9871 - accuracy: 0.2310 - val_loss: 2.1913 - val_accuracy: 0.0870 - lr: 0.0010
# Epoch 3/20
# 56/56 [==============================] - 3s 48ms/step - loss: 1.8993 - accuracy: 0.2969 - val_loss: 2.3655 - val_accuracy: 0.1739 - lr: 0.0010
# Epoch 4/20
# 56/56 [==============================] - 3s 48ms/step - loss: 1.7027 - accuracy: 0.3544 - val_loss: 2.5072 - val_accuracy: 0.1304 - lr: 0.0010
# Epoch 5/20
# 56/56 [==============================] - 3s 47ms/step - loss: 1.6246 - accuracy: 0.4118 - val_loss: 2.3700 - val_accuracy: 0.3043 - lr: 0.0010
# Epoch 6/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.6034 - accuracy: 0.4113 - val_loss: 2.2800 - val_accuracy: 0.2609 - lr: 0.0010
# Epoch 7/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.5081 - accuracy: 0.4626 - val_loss: 2.6319 - val_accuracy: 0.2174 - lr: 0.0010
# Epoch 8/20
# 55/56 [============================>.] - ETA: 0s - loss: 1.4420 - accuracy: 0.4670
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 56/56 [==============================] - 3s 46ms/step - loss: 1.4401 - accuracy: 0.4665 - val_loss: 2.5718 - val_accuracy: 0.3043 - lr: 0.0010
# Epoch 9/20
# 56/56 [==============================] - 3s 45ms/step - loss: 1.3835 - accuracy: 0.5039 - val_loss: 2.3492 - val_accuracy: 0.2174 - lr: 3.0000e-04
# Epoch 10/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.3776 - accuracy: 0.5089 - val_loss: 2.1751 - val_accuracy: 0.3043 - lr: 3.0000e-04
# Epoch 11/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.3541 - accuracy: 0.5095 - val_loss: 2.2435 - val_accuracy: 0.3478 - lr: 3.0000e-04
# Epoch 12/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.3169 - accuracy: 0.5229 - val_loss: 2.3034 - val_accuracy: 0.3043 - lr: 3.0000e-04
# Epoch 13/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.3261 - accuracy: 0.5123 - val_loss: 2.3011 - val_accuracy: 0.2609 - lr: 3.0000e-04
# Epoch 14/20
# 56/56 [==============================] - ETA: 0s - loss: 1.2991 - accuracy: 0.5273
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001.
# 56/56 [==============================] - 3s 46ms/step - loss: 1.2991 - accuracy: 0.5273 - val_loss: 2.4904 - val_accuracy: 0.2609 - lr: 3.0000e-04
# Epoch 15/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.2686 - accuracy: 0.5285 - val_loss: 2.2823 - val_accuracy: 0.3043 - lr: 1.0000e-04
# Epoch 16/20
# 56/56 [==============================] - 3s 45ms/step - loss: 1.2556 - accuracy: 0.5385 - val_loss: 2.3606 - val_accuracy: 0.3478 - lr: 1.0000e-04
# Epoch 17/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.2491 - accuracy: 0.5262 - val_loss: 2.2996 - val_accuracy: 0.3043 - lr: 1.0000e-04
# Epoch 18/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.2417 - accuracy: 0.5346 - val_loss: 2.5476 - val_accuracy: 0.3043 - lr: 1.0000e-04
# Epoch 19/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.2436 - accuracy: 0.5441 - val_loss: 2.3506 - val_accuracy: 0.3478 - lr: 1.0000e-04
# Epoch 20/20
# 56/56 [==============================] - 3s 46ms/step - loss: 1.2295 - accuracy: 0.5469 - val_loss: 2.3380 - val_accuracy: 0.3043 - lr: 1.0000e-04

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Yes there is still scope for improvement. The issue is with the amount of training data. Since we have very less training data we might add augument and create more samples.

# %% [markdown]
# #### Distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
labels = {0 : "actinic", 1: "basel", 2: "dermatofibroma", 3: "melanoma", 4: "nevus",
          5: "pigmented", 6: "seborrheic", 7: "squamous", 8: "vascular"}

def get_classes_distribution(data):
    # Get the count for each label
    label_counts = data['label'].value_counts()

    # Get total number of samples
    total_samples = len(data)


    # Count the number of items in each class
    for i in range(len(label_counts)):
        label = labels[label_counts.index[i]]
        count = label_counts.values[i]
        percent = (count / total_samples) * 100
        print("{:<20s}:   {} or {}%".format(label, count, percent))

# %%
get_classes_distribution(train_df)
# Out:
# nevus               :   462 or 20.634211701652525%
# vascular            :   438 or 19.56230460026798%
# squamous            :   376 or 16.793211255024566%
# basel               :   357 or 15.944618133095132%
# seborrheic          :   181 or 8.083966056275123%
# pigmented           :   139 or 6.208128628852166%
# actinic             :   114 or 5.091558731576597%
# melanoma            :   95 or 4.242965609647164%
# dermatofibroma      :   77 or 3.439035283608754%

# %% [markdown]
# #### The findings are as follows
# #### - classes dermatofibroma, melanoma least number of samples
# #### - classes nevus, vascular dominate the data in terms proportionate number of samples

# %% [markdown]
# #### Fixingclass imbalance
# #### **Context:** Using python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (8.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.65.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.22.4)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500
.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000346.jpg_bda4d475-b77e-462d-8dea-c4dc9292ec8e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000097.jpg_a8256f09-c74c-45d8-b31e-a7387f8e412c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000097.jpg_18e775ae-a428-4213-9749-3731e4bf17c1.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000525.jpg_09b75515-160c-4dc6-810c-5d5158be6e5e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000436.jpg_361dcc94-84b5-4209-9e0a-21913457c4b1.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0024707.jpg_6b01536a-2b85-41d1-8e8e-0d73a30fa721.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000544.jpg_40033841-be6d-4f5c-a94c-43d617ceb23f.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0028990.jpg_65d5e072-b4ca-46d2-88e1-dd918ed6b95a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000378.jpg_cd4ef1b6-00f7-4053-ac45-b9971c6a07da.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000316.jpg_01e822ef-d12b-4789-b748-5038b31b3ba2.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000038.jpg_385786a7-dcbe-4d0b-b922-9891371a69fd.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000389.jpg_b7c623ab-feb7-4539-991e-600eb8ebcfcc.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000342.jpg_dd22fffe-4f33-45f9-a528-b69707fe01a5.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000021.jpg_9c2b6cf7-21b9-492a-aa6b-93a44da74b59.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000356.jpg_541c565b-cdf7-4396-ae29-0162299046ca.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0024763.jpg_44a2afd1-2ec7-4328-a110-ff17c82acabf.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000380.jpg_d3237e11-f6aa-4dd1-b77b-fce9e0a6d29c.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000391.jpg_510047fc-b306-4606-b9ed-6880f18a28f4.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000239.jpg_76cd3af1-8a82-426a-8c82-6354dca7aaf9.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000324.jpg_9c9a459d-bb82-4aa7-9207-96f1b0ae8ead.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000451.jpg_a059372a-9ebf-48ff-b09a-b96c6684ea65.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000391.jpg_dbe665ee-14c6-4a9b-9e7b-1a0fee289e6e.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000099.jpg_ab620939-3d6d-4e18-869a-128fbf6d41e0.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000061.jpg_4c1345cb-b9a3-4256-aa8e-9d8a9687ee5a.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000097.jpg_763acdda-7482-40b3-a137-217374364bf5.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000423.jpg_8659f741-a83c-4c27-b1fb-a2c0dafdaf48.jpg',
#  '/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000379.jpg_7e2edb92-1d09-406b-b24a-dcb0e6945e1a.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
path_list = [x for x in glob(os.path.join(data_dir_train,'*','*.jpg'))]

# %%
lesion_list = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train,'*','*.jpg'))]

# %%
dataframe_dict = dict(zip(path_list, lesion_list))

# %%
original_df = pd.DataFrame(list(dataframe_dict.items()),columns=['Path','Label'])

# %%
original_df['Label'].value_counts()
# Out:
# Train    2239
# Name: Label, dtype: int64

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)
# Out:
# <ipython-input-47-17a6b079869a>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()
# Out:
# Train                         2239
# actinic keratosis              500
# nevus                          500
# seborrheic keratosis           500
# dermatofibroma                 500
# pigmented benign keratosis     500
# vascular lesion                500
# squamous cell carcinoma        500
# basal cell carcinoma           500
# melanoma                       500
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# ####  Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# ####  Create a training dataset

# %%
data_dir_train="/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %%
data_dir_test = "/content/drive/MyDrive/Colab Notebooks/CNN-Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/"
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_test,
  seed=123,
  validation_split = 0.2,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 118 files belonging to 9 classes.
# Using 23 files for validation.

# %% [markdown]
# #### Create model

# %%
## your code goes here
num_classes = 9
model = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.Rescaling(1.0/255),
  tf.keras.layers.Conv2D(32, (3, 3), padding="same", activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(128, (3, 3), padding="same", activation='relu'),
  tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Conv2D(256, (3, 3), activation='relu'),
  #tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(num_classes)
  # No Softmax Activation layer implied from_logits=True
])

# %% [markdown]
# #### Compile your model

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
callback = tf.keras.callbacks.ReduceLROnPlateau(
  monitor='val_accuracy', patience=3, factor=0.1, min_lr=0.0001, verbose=1
)

# %%
model.build(input_shape=(None,180,180,3))

# %% [markdown]
# ####  Train your model

# %%
epochs = 30
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs, callbacks=[callback]
)
# Out:
# Epoch 1/30
# 169/169 [==============================] -
- val_accuracy: 0.8300 - lr: 0.0010
# Epoch 22/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.2154 - accuracy: 0.9129
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 169/169 [==============================] - 21s 119ms/step - loss: 0.2150 - accuracy: 0.9130 - val_loss: 0.6702 - val_accuracy: 0.8211 - lr: 0.0010
# Epoch 23/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.1214 - accuracy: 0.9496 - val_loss: 0.5401 - val_accuracy: 0.8671 - lr: 1.0000e-04
# Epoch 24/30
# 169/169 [==============================] - 21s 118ms/step - loss: 0.0985 - accuracy: 0.9598 - val_loss: 0.5559 - val_accuracy: 0.8664 - lr: 1.0000e-04
# Epoch 25/30
# 169/169 [==============================] - 21s 117ms/step - loss: 0.0934 - accuracy: 0.9592 - val_loss: 0.5706 - val_accuracy: 0.8649 - lr: 1.0000e-04
# Epoch 26/30
# 169/169 [==============================] - 21s 119ms/step - loss: 0.0894 - accuracy: 0.9596 - val_loss: 0.5819 - val_accuracy: 0.8686 - lr: 1.0000e-04
# Epoch 27/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.0867 - accuracy: 0.9611 - val_loss: 0.6008 - val_accuracy: 0.8664 - lr: 1.0000e-04
# Epoch 28/30
# 169/169 [==============================] - 20s 116ms/step - loss: 0.0846 - accuracy: 0.9625 - val_loss: 0.6162 - val_accuracy: 0.8627 - lr: 1.0000e-04
# Epoch 29/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.0832 - accuracy: 0.9626
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001.
# 169/169 [==============================] - 21s 120ms/step - loss: 0.0832 - accuracy: 0.9625 - val_loss: 0.6322 - val_accuracy: 0.8619 - lr: 1.0000e-04
# Epoch 30/30
# 169/169 [==============================] - 20s 117ms/step - loss: 0.0820 - accuracy: 0.9640 - val_loss: 0.6413 - val_accuracy: 0.8619 - lr: 1.0000e-04

# %% [markdown]
# ####  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Analysis of results:
# - We can see that using Augumentor- the class imbalance was addressed by generating more sample images per class and aiding in learning process.
# - This also addressed the overfit problem which we were seeing in our initial model design
# - Model accuracy went up to nearly 80-90% which is significant

# %% [markdown]
# ## **Summary**
#  - Model Building & training :
#    - Created a CNN model, which can accurately detect 9 classes present in the dataset. While building the model, rescale images to normalize pixel values between (0,1).
#    - Selected 'adam' optimiser and loss function 'tf.losses.SparseCategoricalCrossentropy(from_logits=True)' for model training
#    - Train the model for ~20 epochs
#  - The data augmentation strategy with random zoom, rotation, flip was chosen to resolve overfitting
#  - Model Building & training on the augmented data :
#     - Created a CNN model, which can accurately detect 9 classes present in the dataset. While building the model rescale images to normalize pixel values between (0,1).
#     - Selected 'adam' optimiser and loss function 'tf.losses.SparseCategoricalCrossentropy(from_logits=True)' for model training
#     - Train the model for ~20 epochs
#     - The dropout helped in reducing the overfit problem along with data augumentation
#  - On examining the current class distribution in the training dataset
#     - classes dermatofibroma, melanoma least number of samples
#     - classes nevus, vascular dominate the data in terms proportionate number of samples
#  - Rectified class imbalances present in the training dataset with Augmentor library
#  - Model Building & training on the rectified class imbalance data :
#    - Created a CNN model, which can accurately detect 9 classes present in the dataset. While building the model rescale images to normalize pixel values between (0,1).
#     - Selected 'adam' optimiser and loss function 'tf.losses.SparseCategoricalCrossentropy(from_logits=True)' for model training
#     - Train the model for ~30 epochs
#     - This increased the model accuracy to nearly 80-90% which is very significant
